# %%
with open("train_model.py", "r") as f: code = f.read()
code = code.replace('"multinli_1.0/multinli_1.0/multinli_1.0_train.jsonl"', '"multinli_1.0_train.jsonl"')
code = code.replace('"multinli_1.0/multinli_1.0/multinli_1.0_dev_matched.jsonl"', '"multinli_1.0_dev_matched.jsonl"')
code = code.replace('"SciTailV1.1/SciTailV1.1/tsv_format/scitail_1.0_train.tsv"', '"scitail_1.0_train.tsv"')
code = code.replace('"SciTailV1.1/SciTailV1.1/tsv_format/scitail_1.0_dev.tsv"', '"scitail_1.0_dev.tsv"')
with open("train_model.py", "w") as f: f.write(code)
print("✅ Paths fixed")
# Out:
# ✅ Paths fixed

# %%
# !pip install transformers datasets scikit-learn tqdm -q
print("✅ Dependencies installed")
# Out:
# ✅ Dependencies installed

# %%
# !python train_model.py
# Out:
# 🖥️  Device: cuda
#
# 📦 Loading datasets …
#   ✅ MultiNLI loaded from multinli_1.0_train.jsonl: 392,702 samples
#   ✅ MultiNLI loaded from multinli_1.0_dev_matched.jsonl: 9,815 samples
#   ⚠️  SciTail file not found: scitail_1.0_train.tsv
#      → Trying HuggingFace datasets fallback …
# ...
# README.md: 10.1kB [00:00, 22.8MB/s]
# tsv_format/train-00000-of-00001.parquet: 100% 1.57M/1.57M [00:01<00:00, 923kB/s]
# tsv_format/test-00000-of-00001.parquet: 100% 162k/162k [00:00<00:00, 265kB/s]
# tsv_format/validation-00000-of-00001.par(…): 100% 99.8k/99.8k [00:01<00:00, 70.7kB/s]
# Generating train split: 100% 23097/23097 [00:00<00:00, 420970.51 examples/s]
# Generating test split: 100% 2126/2126 [00:00<00:00, 492738.59 examples/s]
# Generating validation split: 100% 1304/1304 [00:00<00:00, 413219.43 examples/s]
#   ✅ SciTail (HF fallback) loaded: 23,097 samples
#   ✅ SciTail loaded from scitail_1.0_dev.tsv: 1,304 samples
#
# 🔀 Merging datasets …
#
# ...
